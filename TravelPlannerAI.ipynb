# %% [markdown]
# <a href="https://colab.research.google.com/github/0sakA/MyProjects/blob/main/TravelPlannerAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
import random

def greet():
    print("Hello! I'm your Travel Chatbot. Let me suggest 3 locations for you.")

def suggest_locations():
    locations = [
        {
            "name": "Paris",
            "top_places": ["Eiffel Tower", "Louvre Museum", "Notre-Dame Cathedral"],
            "hotels": ["Hotel Parisien", "Elysée Palace Hotel", "Ritz Hotel"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Le Jules Verne", "Chez L'Ami Jean", "Le Comptoir du Relais"],
            "visiting_sites": ["Seine River Cruise", "Montmartre", "Champs-Élysées"]
        },
{
            "name": "Tokyo",
            "top_places": ["Tokyo Tower", "Asakusa Temple", "Shinjuku Gyoen National Garden"],
            "hotels": ["Tokyo Inn", "Shangri-La Hotel", "Park Hyatt Tokyo"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Sukiyabashi Jiro", "Ippudo Ramen", "Robot Restaurant"],
            "visiting_sites": ["Akihabara", "Harajuku", "Tsukiji Fish Market"]
        },
        {
            "name": "New York",
            "top_places": ["Statue of Liberty", "Central Park", "Times Square"],
            "hotels": ["The Plaza Hotel", "Waldorf Astoria", "Ritz-Carlton"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Le Bernardin", "Katz's Delicatessen", "Shake Shack"],
            "visiting_sites": ["Empire State Building", "Brooklyn Bridge", "Museum of Modern Art"]
        },
        {
            "name": "Rome",
            "top_places": ["Colosseum", "Vatican City", "Trevi Fountain"],
            "hotels": ["Hotel Romanico Palace", "Hotel Artemide", "Palazzo Montemartini"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Trattoria da Teo", "Antico Arco", "La Pergola"],
            "visiting_sites": ["Roman Forum", "Pantheon", "Spanish Steps"]
        },
        {
            "name": "Sydney",
            "top_places": ["Sydney Opera House", "Bondi Beach", "Royal Botanic Garden"],
            "hotels": ["Four Seasons Hotel", "Shangri-La Hotel", "InterContinental Sydney"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Quay", "Tetsuya's", "Bennelong"],
            "visiting_sites": ["Sydney Harbour Bridge", "Taronga Zoo", "Manly Beach"]
        },

        {
            "name": "Barcelona",
            "top_places": ["Sagrada Familia", "Park Güell", "Barri Gotic"],
            "hotels": ["Hotel Arts Barcelona", "W Barcelona", "Majestic Hotel & Spa"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Tickets", "El Celler de Can Roca", "Disfrutar"],
            "visiting_sites": ["La Rambla", "Casa Batlló", "Montjuïc"]
        },
        {
            "name": "Cairo",
            "top_places": ["Pyramids of Giza", "Egyptian Museum", "Khan El Khalili Bazaar"],
            "hotels": ["Four Seasons Hotel Cairo", "Kempinski Nile Hotel", "Sofitel Cairo Nile El Gezirah"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Abou Tarek Koshary", "Kebdet El Prince", "Naguib Mahfouz Cafe"],
            "visiting_sites": ["Citadel of Saladin", "Mosque of Muhammad Ali", "Coptic Cairo"]
        },
        {
            "name": "Rio de Janeiro",
            "top_places": ["Christ the Redeemer", "Sugarloaf Mountain", "Copacabana Beach"],
            "hotels": ["Belmond Copacabana Palace", "Hotel Fasano Rio de Janeiro", "Grand Hyatt Rio de Janeiro"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Aprazível", "Churrascaria Palace", "Bar Urca"],
            "visiting_sites": ["Selarón Steps", "Maracanã Stadium", "Tijuca National Park"]
        },
        {
            "name": "Amsterdam",
            "top_places": ["Anne Frank House", "Van Gogh Museum", "Canal Cruise"],
            "hotels": ["Hotel Pulitzer", "W Amsterdam", "Conservatorium Hotel"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["De Kas", "The Pancake Bakery", "Balthazar's Keuken"],
            "visiting_sites": ["Rijksmuseum", "Red Light District", "Vondelpark"]
        },
        {
            "name": "Dubai",
            "top_places": ["Burj Khalifa", "The Dubai Mall", "Palm Jumeirah"],
            "hotels": ["Burj Al Arab", "Atlantis The Palm", "Jumeirah Beach Hotel"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Pierchic", "Al Mahara", "Zuma"],
            "visiting_sites": ["Dubai Fountain", "Dubai Marina", "Ski Dubai"]
        },
        {
            "name": "Bangkok",
            "top_places": ["Grand Palace", "Wat Arun", "Chatuchak Weekend Market"],
            "hotels": ["Mandarin Oriental, Bangkok", "Centara Grand at CentralWorld", "Shangri-La Hotel, Bangkok"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Gaggan", "Cabbages & Condoms", "Vertigo at Banyan Tree"],
            "visiting_sites": ["Jim Thompson House", "Lumpini Park", "Asiatique The Riverfront"]
        },
        {
            "name": "Cape Town",
            "top_places": ["Table Mountain", "Robben Island", "V&A Waterfront"],
            "hotels": ["Belmond Mount Nelson Hotel", "One&Only Cape Town", "Cape Grace Hotel"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["The Test Kitchen", "La Colombe", "Gold Restaurant"],
            "visiting_sites": ["Kirstenbosch National Botanical Garden", "Bo-Kaap", "Cape of Good Hope"]
        },
        {
            "name": "Prague",
            "top_places": ["Charles Bridge", "Prague Castle", "Old Town Square"],
            "hotels": ["Aria Hotel Prague", "Four Seasons Hotel Prague", "Hotel Paris Prague"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Kampa Park", "Café Savoy", "La Degustation Bohême Bourgeoise"],
            "visiting_sites": ["St. Vitus Cathedral", "Lennon Wall", "Prague Astronomical Clock"]
        },

        {
            "name": "Copenhagen",
            "top_places": ["Tivoli Gardens", "The Little Mermaid", "Nyhavn"],
            "hotels": ["Nimb Hotel", "Radisson Collection Royal Hotel", "Hotel d'Angleterre"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Noma", "Geranium", "Schønnemann"],
            "visiting_sites": ["Rosenborg Castle", "Amalienborg Palace", "National Museum of Denmark"]
        },
        {
            "name": "Seoul",
            "top_places": ["Gyeongbokgung Palace", "Bukchon Hanok Village", "N Seoul Tower"],
            "hotels": ["The Shilla Seoul", "Lotte Hotel Seoul", "Four Seasons Hotel Seoul"],
            "hotel_sites": ["booking.com", "expedia.com", "hotels.com"],
            "restaurants": ["Jungsik", "Gangnam Myeonok", "Gwangjang Market"],
            "visiting_sites": ["Changdeokgung Palace", "Insadong", "Hangang Park"]
        }
    ]

    suggested_locations = random.sample(locations, 3)

    print("I suggest the following locations:")
    for i, location in enumerate(suggested_locations, start=1):
        print(f"{i}. {location['name']}")

    return suggested_locations

def display_location_data(location):
    print(f"\n{location['name']} Information:")
    print(f"Top Places to Visit: {', '.join(location['top_places'])}")


    user_choice = input("\nWould you like to visit any of these places? (yes/no): ").lower()

    if user_choice == "yes":
        print("\nEnter the number corresponding to the location you'd like to visit:")
        for i, top_place in enumerate(location['top_places'], start=1):
            print(f"{i}. {top_place}")

        user_selection = int(input("Enter the number: "))
        if 1 <= user_selection <= len(location['top_places']):
            selected_place = location['top_places'][user_selection - 1]
            print(f"\nGreat choice! You can visit {selected_place}.")

            # Select one random hotel with available rooms
            selected_hotel = random.choice(location['hotels'])
            selected_site = random.choice(location['hotel_sites'])

            print(f"\n{selected_hotel} has rooms available. Book at {selected_site}")

            # Select one random site and two random restaurants
            selected_site = random.choice(location['visiting_sites'])
            selected_restaurants = random.sample(location['restaurants'], 2)
            relationship = random.sample(["close", "amazing", "good", "fun"],2)

            print(f"\nWhile you're there, you might want to check out {selected_site}.\n")
            print(f"I also recommend trying {selected_restaurants[0]} restaurant - it's {relationship[1]} around {selected_site}.")
            print(f"Another option is {selected_restaurants[1]} - restaurant it's also {relationship[0]} around {selected_site}.")

        else:
            print("Invalid selection. Please try again.")
    else:
        # If the user says "no," suggest available hotels
        num_hotels = min(random.randint(0, 15), len(location['hotels']))
        selected_hotels = random.sample(location['hotels'], num_hotels)
        selected_sites = random.sample(location['hotel_sites'], num_hotels)

        print("\nHotels Available:")
        for hotel, site in zip(selected_hotels, selected_sites):
            print(f"{hotel} - Book at {site}")


def get_user_input():
    print("Where would you like to go? ")
    return input("You: ").lower()

def main():
    greet()

    locations = suggest_locations()

    user_input = get_user_input()


    for location in locations:
        if location['name'].lower() in user_input:
            display_location_data(location)
            break
    else:
        print("I'm sorry, I didn't understand that. Please specify your own destination.")

if __name__ == "__main__":
    main()
# Out:
# Hello! I'm your Travel Chatbot. Let me suggest 3 locations for you.
# I suggest the following locations:
# 1. Paris
# 2. Dubai
# 3. Amsterdam
# Where would you like to go?
# You: paris
#
# Paris Information:
# Top Places to Visit: Eiffel Tower, Louvre Museum, Notre-Dame Cathedral
#
# Would you like to visit any of these places? (yes/no): yes
#
# Enter the number corresponding to the location you'd like to visit:
# 1. Eiffel Tower
# 2. Louvre Museum
# 3. Notre-Dame Cathedral
# Enter the number: 2
#
# Great choice! You can visit Louvre Museum.
#
# Hotel Parisien has rooms available. Book at expedia.com
#
# While you're there, you might want to check out Champs-Élysées.
#
# I also recommend trying Le Comptoir du Relais restaurant - it's close around Champs-Élysées.
# Another option is Chez L'Ami Jean - restaurant it's also fun around Champs-Élysées.
